# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community langchain-chroma
# Out:
# Requirement already satisfied: langchain in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (0.3.27)
# Requirement already satisfied: chromadb in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (1.3.4)
# Requirement already satisfied: openai in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (2.7.1)
# Requirement already satisfied: tiktoken in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (0.12.0)
# Requirement already satisfied: pypdf in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (6.2.0)
# Requirement already satisfied: langchain_openai in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (0.3.35)
# Requirement already satisfied: langchain-community in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (0.3.31)
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.4.41)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (6.0.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (2.3.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.4.3)
#   Downloading langchain_chroma-0.2.6-py3-none-any.whl (12 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: packaging>=19.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: certifi in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: coloredlogs in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.0)
# Requirement already satisfied: sympy in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: greenlet>=1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.1.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: typer-slim in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.20.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\rahuldevjoshi\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Installing collected packages: langchain-chroma
# Successfully installed langchain-chroma-0.2.6
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import OpenAIEmbeddings

# %%
from langchain_chroma import Chroma

# %%
from langchain.schema import Document

# %%
doc1 = Document(
    page_content = "Virat Kohli is a relentless run-scorer known for his unmatched consistency and fiery passion. His aggression drives the team’s energy on and off the field. Kohli embodies discipline, intensity, and the hunger to win every battle.",
    metadata={"team":"Royal Challengers Bangalore"}
)

doc2 = Document(
    page_content = "Rohit Sharma is a master of timing and elegance, turning pressure into poetry with the bat. His calm captaincy brings balance to chaos. Rohit’s effortless stroke play makes batting look like an art form.",
    metadata={"team":"Mumbai Indians"}
)

doc3 = Document(
    page_content = "MS Dhoni, The calm within the storm, a leader who redefined composure. His sharp mind and finishing prowess made him India’s greatest captain. Dhoni leads not by words, but by timeless example.",
    metadata={"team":"Chennai Super Kings"}
)

doc4 = Document(
    page_content = "Jasprit Bumrah is a bowling genius who mixes precision with pure menace. His unorthodox action and lethal yorkers strike fear in batsmen. Bumrah is the silent assassin of modern cricket.",
    metadata={"team":"Mumbai Indians"}
)

doc5 = Document(
    page_content = "Ravindra Jadeja is a true all-rounder blending agility, spin, and grit. His fielding turns half-chances into miracles. Jadeja’s versatility makes him India’s ultimate game-changer.",
    metadata={"team":"Chennai Super Kings"}
)

# %%
docs = [doc1,doc2,doc3,doc4,doc5]

# %%
vector_store=Chroma(
    embedding_function = OpenAIEmbeddings(),
    persist_directory='chroma_db',
    collection_name='sample'
)

# %%
vector_store.add_documents(docs)
# Out:
# ['93e77921-474c-4d75-b3dc-1d2cc06e5250',
#  'f5261633-9474-41c8-a1b0-b271b66049c9',
#  'bb43483e-005e-48bc-ba07-6dc5d44b40be',
#  'f2e86c68-8eeb-46da-ae4b-ca05df6870c2',
#  '7e100a75-5fae-4beb-8975-2c46fe49f210']

# %%
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['93e77921-474c-4d75-b3dc-1d2cc06e5250',
#   'f5261633-9474-41c8-a1b0-b271b66049c9',
#   'bb43483e-005e-48bc-ba07-6dc5d44b40be',
#   'f2e86c68-8eeb-46da-ae4b-ca05df6870c2',
#   '7e100a75-5fae-4beb-8975-2c46fe49f210'],
#  'embeddings': array([[-0.00168072, -0.00983617,  0.02552507, ..., -0.02292099,
#           0.00012227,  0.0087404 ],
#         [ 0.00711092,  0.00773647,  0.01414523, ...,  0.00322353,
#           0.01455376, -0.02601803],
#         [-0.00926812,  0.01934615,  0.00802715, ..., -0.01288655,
#          -0.00146386, -0.00802062],
#         [-0.04171478,  0.02002828,  0.01984691, ..., -0.01974327,
#           0.00865387, -0.01079791],
#         [-0.00701041,  0.00532016,  0.0344744 , ..., -0.02172701,
#          -0.00258624, -0.00833634]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is a relentless run-scorer known for his unmatched consistency and fiery passion. His aggression drives the team’s energy on and off the field. Kohli embodies discipline, intensity, and the hunger to win every battle.',
#   'Rohit Sharma is a master of timing and elegance, turning pressure into poetry with the bat. His calm captaincy brings balance to chaos. Rohit’s effortless stroke play makes batting look like an art form.',
#   'MS Dhoni, The calm within the storm, a leader who redefined composure. His sharp mind and finishing prowess made him India’s greatest captain. Dhoni leads not by words, but by timeless example.',
#   'Jasprit Bumrah is a bowling genius who mixes precision with pure menace. His unorthodox action and lethal yorkers strike fear in batsmen. Bumrah is the silent assassin of modern cricket.',
#   'Ravindra Jadeja is a true all-rounder blending agility, spin, and grit. His fielding turns half-chances into miracles. Jadeja’s versatility makes him India’s ultimate game-changer.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [Document(id='f2e86c68-8eeb-46da-ae4b-ca05df6870c2', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is a bowling genius who mixes precision with pure menace. His unorthodox action and lethal yorkers strike fear in batsmen. Bumrah is the silent assassin of modern cricket.'),
#  Document(id='7e100a75-5fae-4beb-8975-2c46fe49f210', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a true all-rounder blending agility, spin, and grit. His fielding turns half-chances into miracles. Jadeja’s versatility makes him India’s ultimate game-changer.')]

# %%
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(id='f2e86c68-8eeb-46da-ae4b-ca05df6870c2', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is a bowling genius who mixes precision with pure menace. His unorthodox action and lethal yorkers strike fear in batsmen. Bumrah is the silent assassin of modern cricket.'),
#   0.3617185950279236),
#  (Document(id='7e100a75-5fae-4beb-8975-2c46fe49f210', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a true all-rounder blending agility, spin, and grit. His fielding turns half-chances into miracles. Jadeja’s versatility makes him India’s ultimate game-changer.'),
#   0.41447848081588745)]

# %%
vector_store.similarity_search_with_score(
    query='',
    filter={"team":"Chennai Super Kings"}
)
# Out:
# [(Document(id='bb43483e-005e-48bc-ba07-6dc5d44b40be', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, The calm within the storm, a leader who redefined composure. His sharp mind and finishing prowess made him India’s greatest captain. Dhoni leads not by words, but by timeless example.'),
#   0.631961464881897),
#  (Document(id='7e100a75-5fae-4beb-8975-2c46fe49f210', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a true all-rounder blending agility, spin, and grit. His fielding turns half-chances into miracles. Jadeja’s versatility makes him India’s ultimate game-changer.'),
#   0.6402850151062012)]

# %%
updated_doc1 = Document(
    page_content = "Virat Kohli is a fearless opener who redefined aggression in Test cricket. His explosive stroke play turned matches within sessions. Kohli played with instinct, freedom, and an unshakable smile.",
    metadata={"team":"Royal Challengers Bangalore"}
)

vector_store.update_document(document_id = '93e77921-474c-4d75-b3dc-1d2cc06e5250', document=updated_doc1)

# %%
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['93e77921-474c-4d75-b3dc-1d2cc06e5250',
#   'f5261633-9474-41c8-a1b0-b271b66049c9',
#   'bb43483e-005e-48bc-ba07-6dc5d44b40be',
#   'f2e86c68-8eeb-46da-ae4b-ca05df6870c2',
#   '7e100a75-5fae-4beb-8975-2c46fe49f210'],
#  'embeddings': array([[-0.00626929,  0.01015527,  0.02371526, ..., -0.02272003,
#           0.00965765,  0.00638387],
#         [ 0.00711092,  0.00773647,  0.01414523, ...,  0.00322353,
#           0.01455376, -0.02601803],
#         [-0.00926812,  0.01934615,  0.00802715, ..., -0.01288655,
#          -0.00146386, -0.00802062],
#         [-0.04171478,  0.02002828,  0.01984691, ..., -0.01974327,
#           0.00865387, -0.01079791],
#         [-0.00701041,  0.00532016,  0.0344744 , ..., -0.02172701,
#          -0.00258624, -0.00833634]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is a fearless opener who redefined aggression in Test cricket. His explosive stroke play turned matches within sessions. Kohli played with instinct, freedom, and an unshakable smile.',
#   'Rohit Sharma is a master of timing and elegance, turning pressure into poetry with the bat. His calm captaincy brings balance to chaos. Rohit’s effortless stroke play makes batting look like an art form.',
#   'MS Dhoni, The calm within the storm, a leader who redefined composure. His sharp mind and finishing prowess made him India’s greatest captain. Dhoni leads not by words, but by timeless example.',
#   'Jasprit Bumrah is a bowling genius who mixes precision with pure menace. His unorthodox action and lethal yorkers strike fear in batsmen. Bumrah is the silent assassin of modern cricket.',
#   'Ravindra Jadeja is a true all-rounder blending agility, spin, and grit. His fielding turns half-chances into miracles. Jadeja’s versatility makes him India’s ultimate game-changer.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
vector_store.delete(ids=['93e77921-474c-4d75-b3dc-1d2cc06e5250'])

# %%
vector_store.get(include=['embeddings','documents','metadatas'])
